# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
def scheduler(epoch):
    if epoch < 2:
        return 0.001
    elif epoch < 6:
        return 0.0001
    else:
        return 0.00001

learning_rate_scheduler = LearningRateScheduler(scheduler, verbose=1)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, callbacks=[learning_rate_scheduler])
# Out:
# Train on 60000 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/10
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.4761 - accuracy: 0.8296
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/10
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.3617 - accuracy: 0.8671
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/10
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.2827 - accuracy: 0.8960
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/10
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.2710 - accuracy: 0.9008
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/10
# 60000/60000 [==============================] - 12s 192us/sample - loss: 0.2638 - accuracy: 0.9026
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/10
# 60000/60000 [==============================] - 13s 212us/sample - loss: 0.2566 - accuracy: 0.9053
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 7/10
# 60000/60000 [==============================] - 13s 209us/sample - loss: 0.2458 - accuracy: 0.9091
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 8/10
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.2438 - accuracy: 0.9100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 9/10
# 60000/60000 [==============================] - 12s 192us/sample - loss: 0.2431 - accuracy: 0.9104
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 10/10
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.2422 - accuracy: 0.9107
